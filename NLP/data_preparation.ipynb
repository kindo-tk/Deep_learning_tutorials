# %% [markdown]
# ## Preparing my own data from API key then performing text preprocessing

# %%
import requests
import pandas as pd
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

API_KEY = "8265bd1679663a7ea12ac168da84d2e8"
BASE_URL = "https://api.themoviedb.org/3/movie/top_rated"

# Create session with retry & backoff
session = requests.Session()
retry_strategy = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
session.mount("https://", HTTPAdapter(max_retries=retry_strategy))

all_movies = []

for page in range(1, 527): 
    try:
        response = session.get(
            BASE_URL,
            params={
                "api_key": API_KEY,
                "language": "en-US",
                "page": page
            },
            timeout=10
        )
        response.raise_for_status()

        data = response.json()
        all_movies.extend(data.get("results", []))

        print(f"Fetched page {page}, total movies: {len(all_movies)}")
        time.sleep(0.5)  # prevents connection reset

    except requests.exceptions.RequestException as e:
        print(f"Failed on page {page}: {e}")
        time.sleep(5)
        continue
# Out:
# Fetched page 1, total movies: 20
# Fetched page 2, total movies: 40
# Fetched page 3, total movies: 60
# Fetched page 4, total movies: 80
# Fetched page 5, total movies: 100
# Fetched page 6, total movies: 120
# Fetched page 7, total movies: 140
# Fetched page 8, total movies: 160
# Fetched page 9, total movies: 180
# Fetched page 10, total movies: 200
# Fetched page 11, total movies: 220
# Fetched page 12, total movies: 240
# Fetched page 13, total movies: 260
# Fetched page 14, total movies: 280
# Fetched page 15, total movies: 300
# Fetched page 16, total movies: 320
# Fetched page 17, total movies: 340
# Fetched page 18, total movies: 360
# Fetched page 19, total movies: 380
# Fetched page 20, total movies: 400
# Fetched page 21, total movies: 420
# Fetched page 22, total movies: 440
# Fetched page 23, total movies: 460
# Fetched page 24, total movies: 480
# Fetched page 25, total movies: 500
# Fetched page 26, total movies: 520
# Fetched page 27, total movies: 540
# Fetched page 28, total movies: 560
# Fetched page 29, total movies: 580
# Fetched page 30, total movies: 600
# Fetched page 31, total movies: 620
# Fetched page 32, total movies: 640
# Fetched page 33, total movies: 660
# Fetched page 34, total movies: 680
# Fetched page 35, total movies: 700
# Fetched page 36, total movies: 720
# Fetched page 37, total movies: 740
# Fetched page 38, total movies: 760
# Fetched page 39, total movies: 780
# Fetched page 40, total movies: 800
# Fetched page 41, total movies: 820
# Fetched page 42, total movies: 840
# Fetched page 43, total movies: 860
# Fetched page 44, total movies: 880
# Fetched page 45, total movies: 900
# Fetched page 46, total movies: 920
# Fetched page 47, total movies: 940
# Fetched page 48, total movies: 960
# Fetched page 49, total movies: 980
# Fetched page 50, total movies: 1000
# Fetched page 51, total movies: 1020
# Fetched page 52, total movies: 1040
# Fetched page 53, total movies: 1060
# Fetched page 54, total movies: 1080
# Fetched page 55, total movies: 1100
# Fetched page 56, total movies: 1120
# Fetched page 57, total movies: 1140
# Fetched page 58, total movies: 1160
# Fetched page 59, total movies: 1180
# Fetched page 60, total movies: 1200
# Fetched page 61, total movies: 1220
# Fetched page 62, total movies: 1240
# Fetched page 63, total movies: 1260
# Fetched page 64, total movies: 1280
# Fetched page 65, total movies: 1300
# Fetched page 66, total movies: 1320
 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=525
# Failed on page 526: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=526

# %%
# Load into pandas
df = pd.DataFrame(all_movies)

print("Final shape:", df.shape)
df.head()
# Out:
# Final shape: (10000, 14)
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg         [18, 80]  238
# 2  False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     26.1332
# 1  Spanning the years 1945 to 1955, a chronicle o...     25.2389
# 2  In the continuing saga of the Corleone crime f...     19.8566
# 3  The true story of how businessman Oskar Schind...     12.9693
# 4  The defense and the prosecution have rested an...     11.4362
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
# 4  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10              12 Angry Men
#
#    video  vote_average  vote_count
# 0  False         8.700       29336
# 1  False         8.685       22142
# 2  False         8.571       13386
# 3  False         8.566       16896
# 4  False         8.500        9579

# %% [markdown]
# ### Loading genres

# %%
GENRE_URL = "https://api.themoviedb.org/3/genre/movie/list?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US"

genre_response = requests.get(GENRE_URL)
genre_data = genre_response.json()

# Build id -> name mapping
genre_map = {
    genre["id"]: genre["name"]
    for genre in genre_data["genres"]
}

# %%
def map_genres(genre_ids):
    return [genre_map.get(gid, "Unknown") for gid in genre_ids]

# %%
df["genre_names"] = df["genre_ids"].apply(map_genres)
df
# Out:
#       adult                     backdrop_path               genre_ids      id  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg                [18, 80]     278
# 1     False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg                [18, 80]     238
# 2     False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg                [18, 80]     240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg         [18, 36, 10752]     424
# 4     False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg                    [18]     389
# ...     ...                               ...                     ...     ...
# 9995  False  /nKJz9OZNZYk8JcUx6oDEgxcDfos.jpg                [28, 35]    9876
# 9996  False  /nGwlHqVQjPjRPPxEiJuaXYoOuIl.jpg      [10749, 35, 10751]   11982
# 9997  False  /t8K8TkiLrrFCBVCIHt8U6nYXwrg.jpg                [53, 27]  234212
# 9998  False  /9wmzKxkmnsoW5gdvW7Iq1mBcKNJ.jpg                    [27]  282813
# 9999  False   /VtFa6Ph0xCO6QJ86ihCrpsDBIO.jpg  [35, 10751, 10749, 14]   10808
#
#      original_language              original_title  \
# 0                   en    The Shawshank Redemption
# 1                   en               The Godfather
# 2                   en       The Godfather Part II
# 3                   en            Schindler's List
# 4                   en                12 Angry Men
# ...                ...                         ...
# 9995                en  Stop! Or My Mom Will Shoot
# 9996                en     Look Who's Talking Now!
# 9997                en                     Demonic
# 9998                en                 The Pyramid
# 9999                en              Dr. Dolittle 2
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...     26.1332
# 1     Spanning the years 1945 to 1955, a chronicle o...     25.2389
# 2     In the continuing saga of the Corleone crime f...     19.8566
# 3     The true story of how businessman Oskar Schind...     12.9693
# 4     The defense and the prosecution have rested an...     11.4362
# ...                                                 ...         ...
# 9995  A tough police sergeant's mother comes to visi...      3.1187
# 9996  When high-powered executive Samantha LeBon hat...      5.7094
# 9997  A police officer and a psychologist investigat...      0.9624
# 9998  An archaeological team attempt to unlock the s...      1.5155
# 9999  A group of beavers ask Dr. Dolittle to save th...      5.7107
#
#                            poster_path release_date  \
# 0     /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1     /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2     /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3     /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4     /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# ...                                ...          ...
# 9995  /yCw4U5FK7C9hVWF2qcLO4EVvkCc.jpg   1992-02-21
# 9996  /73JahFiizkMVsrrslXInmNK54nC.jpg   1993-11-05
# 9997  /ne0wAvbmzk72svslxjuFySrXEKw.jpg   2015-02-12
# 9998  /joPb4PUPP7xClD6XPiQ7laBEtZf.jpg   2014-12-04
# 9999  /asYjHXBoD44B6mLOcZtMfMV3hm1.jpg   2001-06-22
#
#                            title  video  vote_average  vote_count  \
# 0       The Shawshank Redemption  False         8.700       29336
# 1                  The Godfather  False         8.685       22142
# 2          The Godfather Part II  False         8.571       13386
# 3               Schindler's List  False         8.566       16896
# 4                   12 Angry Men  False         8.500        9579
# ...                          ...    ...           ...         ...
# 9995  Stop! Or My Mom Will Shoot  False         5.320        1072
# 9996     Look Who's Talking Now!  False         5.319        1063
# 9997                     Demonic  False         5.318         514
# 9998                 The Pyramid  False         5.317        1123
# 9999              Dr. Dolittle 2  False         5.317        1724
#
#                              genre_names
# 0                         [Drama, Crime]
# 1                         [Drama, Crime]
# 2                         [Drama, Crime]
# 3                  [Drama, History, War]
# 4                                [Drama]
# ...                                  ...
# 9995                    [Action, Comedy]
# 9996           [Romance, Comedy, Family]
# 9997                  [Thriller, Horror]
# 9998                            [Horror]
# 9999  [Comedy, Family, Romance, Fantasy]
#
# [10000 rows x 15 columns]

# %% [markdown]
# ### Making my desired dataset with the columns name, description and genre
#
# |name|description|genre|
# |--|--|--|

# %%
df_final = df[['original_title','overview','genre_names']].copy()

# %%
df_final
# Out:
#                   original_title  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9995  A tough police sergeant's mother comes to visi...
# 9996  When high-powered executive Samantha LeBon hat...
# 9997  A police officer and a psychologist investigat...
# 9998  An archaeological team attempt to unlock the s...
# 9999  A group of beavers ask Dr. Dolittle to save th...
#
#                              genre_names
# 0                         [Drama, Crime]
# 1                         [Drama, Crime]
# 2                         [Drama, Crime]
# 3                  [Drama, History, War]
# 4                                [Drama]
# ...                                  ...
# 9995                    [Action, Comedy]
# 9996           [Romance, Comedy, Family]
# 9997                  [Thriller, Horror]
# 9998                            [Horror]
# 9999  [Comedy, Family, Romance, Fantasy]
#
# [10000 rows x 3 columns]

# %%
df_final.rename(columns = {'original_title':'Name',
                 'overview':'description'}, inplace = True)

df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9995  A tough police sergeant's mother comes to visi...
# 9996  When high-powered executive Samantha LeBon hat...
# 9997  A police officer and a psychologist investigat...
# 9998  An archaeological team attempt to unlock the s...
# 9999  A group of beavers ask Dr. Dolittle to save th...
#
#                              genre_names
# 0                         [Drama, Crime]
# 1                         [Drama, Crime]
# 2                         [Drama, Crime]
# 3                  [Drama, History, War]
# 4                                [Drama]
# ...                                  ...
# 9995                    [Action, Comedy]
# 9996           [Romance, Comedy, Family]
# 9997                  [Thriller, Horror]
# 9998                            [Horror]
# 9999  [Comedy, Family, Romance, Fantasy]
#
# [10000 rows x 3 columns]

# %%
df_final["genre"] = df_final["genre_names"].apply(lambda x: ", ".join(x))

# %%
df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9995  A tough police sergeant's mother comes to visi...
# 9996  When high-powered executive Samantha LeBon hat...
# 9997  A police officer and a psychologist investigat...
# 9998  An archaeological team attempt to unlock the s...
# 9999  A group of beavers ask Dr. Dolittle to save th...
#
#                              genre_names                             genre
# 0                         [Drama, Crime]                      Drama, Crime
# 1                         [Drama, Crime]                      Drama, Crime
# 2                         [Drama, Crime]                      Drama, Crime
# 3                  [Drama, History, War]               Drama, History, War
# 4                                [Drama]                             Drama
# ...                                  ...                               ...
# 9995                    [Action, Comedy]                    Action, Comedy
# 9996           [Romance, Comedy, Family]           Romance, Comedy, Family
# 9997                  [Thriller, Horror]                  Thriller, Horror
# 9998                            [Horror]                            Horror
# 9999  [Comedy, Family, Romance, Fantasy]  Comedy, Family, Romance, Fantasy
#
# [10000 rows x 4 columns]

# %%
df_final.drop('genre_names', axis = 1, inplace = True)

# %%
df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9995  A tough police sergeant's mother comes to visi...
# 9996  When high-powered executive Samantha LeBon hat...
# 9997  A police officer and a psychologist investigat...
# 9998  An archaeological team attempt to unlock the s...
# 9999  A group of beavers ask Dr. Dolittle to save th...
#
#                                  genre
# 0                         Drama, Crime
# 1                         Drama, Crime
# 2                         Drama, Crime
# 3                  Drama, History, War
# 4                                Drama
# ...                                ...
# 9995                    Action, Comedy
# 9996           Romance, Comedy, Family
# 9997                  Thriller, Horror
# 9998                            Horror
# 9999  Comedy, Family, Romance, Fantasy
#
# [10000 rows x 3 columns]

# %%
df_final.to_csv(
    "dataset/tmdb_movies_final.csv",
    index=False,
    encoding="utf-8"
)

# %% [markdown]
# ## Performing text preprocessing on the dataset

# %% [markdown]
# ### Lowercasing

# %%
df_final['description'] = df_final['description'].str.lower()

# %%
df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     imprisoned in the 1940s for the double murder ...
# 1     spanning the years 1945 to 1955, a chronicle o...
# 2     in the continuing saga of the corleone crime f...
# 3     the true story of how businessman oskar schind...
# 4     the defense and the prosecution have rested an...
# ...                                                 ...
# 9995  a tough police sergeant's mother comes to visi...
# 9996  when high-powered executive samantha lebon hat...
# 9997  a police officer and a psychologist investigat...
# 9998  an archaeological team attempt to unlock the s...
# 9999  a group of beavers ask dr. dolittle to save th...
#
#                                  genre
# 0                         Drama, Crime
# 1                         Drama, Crime
# 2                         Drama, Crime
# 3                  Drama, History, War
# 4                                Drama
# ...                                ...
# 9995                    Action, Comedy
# 9996           Romance, Comedy, Family
# 9997                  Thriller, Horror
# 9998                            Horror
# 9999  Comedy, Family, Romance, Fantasy
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Removing HTML tags

# %%
import re 

def remove_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
df_final['description'] = df_final['description'].apply(remove_tags)

# %%
df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     imprisoned in the 1940s for the double murder ...
# 1     spanning the years 1945 to 1955, a chronicle o...
# 2     in the continuing saga of the corleone crime f...
# 3     the true story of how businessman oskar schind...
# 4     the defense and the prosecution have rested an...
# ...                                                 ...
# 9995  a tough police sergeant's mother comes to visi...
# 9996  when high-powered executive samantha lebon hat...
# 9997  a police officer and a psychologist investigat...
# 9998  an archaeological team attempt to unlock the s...
# 9999  a group of beavers ask dr. dolittle to save th...
#
#                                  genre
# 0                         Drama, Crime
# 1                         Drama, Crime
# 2                         Drama, Crime
# 3                  Drama, History, War
# 4                                Drama
# ...                                ...
# 9995                    Action, Comedy
# 9996           Romance, Comedy, Family
# 9997                  Thriller, Horror
# 9998                            Horror
# 9999  Comedy, Family, Romance, Fantasy
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Removing URLs

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'',text)

# %%
df_final['description'] = df_final['description'].apply(remove_url)

# %% [markdown]
# ### Removing punctuations

# %%
import string
exclude = string.punctuation

def remove_punc_optimized(text):
    return text.translate(str.maketrans('','',exclude))

df_final['description'] = df_final['description'].apply(remove_punc_optimized)

# %% [markdown]
# ### Tokenization plus stop word removal

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words("english"))

def tokenize_and_remove_stopwords(text):
    if not isinstance(text, str):
        return []

    tokens = word_tokenize(text)
    return [w for w in tokens if w not in stop_words]

df_final["tokens"] = df_final["description"].apply(tokenize_and_remove_stopwords)

# %%
df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     imprisoned in the 1940s for the double murder ...
# 1     spanning the years 1945 to 1955 a chronicle of...
# 2     in the continuing saga of the corleone crime f...
# 3     the true story of how businessman oskar schind...
# 4     the defense and the prosecution have rested an...
# ...                                                 ...
# 9995  a tough police sergeants mother comes to visit...
# 9996  when highpowered executive samantha lebon hatc...
# 9997  a police officer and a psychologist investigat...
# 9998  an archaeological team attempt to unlock the s...
# 9999  a group of beavers ask dr dolittle to save the...
#
#                                  genre  \
# 0                         Drama, Crime
# 1                         Drama, Crime
# 2                         Drama, Crime
# 3                  Drama, History, War
# 4                                Drama
# ...                                ...
# 9995                    Action, Comedy
# 9996           Romance, Comedy, Family
# 9997                  Thriller, Horror
# 9998                            Horror
# 9999  Comedy, Family, Romance, Fantasy
#
#                                                  tokens
# 0     [imprisoned, 1940s, double, murder, wife, love...
# 1     [spanning, years, 1945, 1955, chronicle, ficti...
# 2     [continuing, saga, corleone, crime, family, yo...
# 3     [true, story, businessman, oskar, schindler, s...
# 4     [defense, prosecution, rested, jury, filing, j...
# ...                                                 ...
# 9995  [tough, police, sergeants, mother, comes, visi...
# 9996  [highpowered, executive, samantha, lebon, hatc...
# 9997  [police, officer, psychologist, investigate, d...
# 9998  [archaeological, team, attempt, unlock, secret...
# 9999  [group, beavers, ask, dr, dolittle, save, habi...
#
# [10000 rows x 4 columns]

# %% [markdown]
# ### Lemmatization

# %%
import spacy

nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

def lemmatize(text):
    if not isinstance(text, str):
        return text

    doc = nlp(text)
    return " ".join(token.lemma_ for token in doc if not token.is_stop)

df_final["lemmatized_overview"] = df_final["description"].apply(lemmatize)

df_final
# Out:
#                             Name  \
# 0       The Shawshank Redemption
# 1                  The Godfather
# 2          The Godfather Part II
# 3               Schindler's List
# 4                   12 Angry Men
# ...                          ...
# 9995  Stop! Or My Mom Will Shoot
# 9996     Look Who's Talking Now!
# 9997                     Demonic
# 9998                 The Pyramid
# 9999              Dr. Dolittle 2
#
#                                             description  \
# 0     imprisoned in the 1940s for the double murder ...
# 1     spanning the years 1945 to 1955 a chronicle of...
# 2     in the continuing saga of the corleone crime f...
# 3     the true story of how businessman oskar schind...
# 4     the defense and the prosecution have rested an...
# ...                                                 ...
# 9995  a tough police sergeants mother comes to visit...
# 9996  when highpowered executive samantha lebon hatc...
# 9997  a police officer and a psychologist investigat...
# 9998  an archaeological team attempt to unlock the s...
# 9999  a group of beavers ask dr dolittle to save the...
#
#                                  genre  \
# 0                         Drama, Crime
# 1                         Drama, Crime
# 2                         Drama, Crime
# 3                  Drama, History, War
# 4                                Drama
# ...                                ...
# 9995                    Action, Comedy
# 9996           Romance, Comedy, Family
# 9997                  Thriller, Horror
# 9998                            Horror
# 9999  Comedy, Family, Romance, Fantasy
#
#                                                  tokens  \
# 0     [imprisoned, 1940s, double, murder, wife, love...
# 1     [spanning, years, 1945, 1955, chronicle, ficti...
# 2     [continuing, saga, corleone, crime, family, yo...
# 3     [true, story, businessman, oskar, schindler, s...
# 4     [defense, prosecution, rested, jury, filing, j...
# ...                                                 ...
# 9995  [tough, police, sergeants, mother, comes, visi...
# 9996  [highpowered, executive, samantha, lebon, hatc...
# 9997  [police, officer, psychologist, investigate, d...
# 9998  [archaeological, team, attempt, unlock, secret...
# 9999  [group, beavers, ask, dr, dolittle, save, habi...
#
#                                     lemmatized_overview
# 0     imprison 1940 double murder wife lover upstand...
# 1     span year 1945 1955 chronicle fictional italia...
# 2     continue saga corleone crime family young vito...
# 3     true story businessman oskar schindler save th...
# 4     defense prosecution rest jury file jury room d...
# ...                                                 ...
# 9995  tough police sergeant mother come visit prompt...
# 9996  highpowered executive samantha lebon hatch sch...
# 9997  police officer psychologist investigate death ...
# 9998  archaeological team attempt unlock secret lost...
# 9999  group beaver ask dr dolittle save habitat logg...
#
# [10000 rows x 5 columns]
